# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext jupyter_black

# %%
import matplotlib.pyplot as plt
from evallm.experiments.change_symbols import (
    change_symbols_experiment,
    plot_symbol_correlations,
)

# %%
model_key = "mistral-nemo-minitron-8B"

# %%
cse = change_symbols_experiment(
    model_key=model_key,
    num_dfas=1000,
    other_symbol_sets=["ABC", "cba", "xyz", "zyx", "123", "234", ("cat", "dog", "bat")],
)

# %%
plt.figure(dpi=200, tight_layout=True)
plot_symbol_correlations(cse)
plt.savefig("../output/different-symbols-correlation.png")
