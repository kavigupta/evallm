# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext jupyter_black

# %%
import matplotlib.pyplot as plt
from evallm.experiments.sequence_completion.is_sc_predicting_novel import (
    novelty_experiment,
    plot_novelty_results,
    control_classifications,
)
from evallm.experiments.transducer_plotting import setup_plot

# %%
model_key = "qwen-2.5-coder-7B"

# %%
all_is_correct, all_classifications = novelty_experiment(1000, model_key)

# %%
setup_plot()
plt.figure(dpi=200, tight_layout=True)
plot_novelty_results(
    all_is_correct, all_classifications, plt.gca(), control_classifications(1000)
)
plt.savefig("../output/novelty-by-correctness")
